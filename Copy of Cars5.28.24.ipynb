# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/mtcars.csv')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
df.head(40)
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df.shape
# Out:
# (32, 12)

# %%
df[df['mpg']>20]
# Out:
#         Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3   Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 7        Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8         Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 17        Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 18     Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# 19  Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 25       Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# ...

# %%
df = df.rename(columns={'Unnamed: 0': 'Make & Model'})

# %%
df.head()
# Out:
#         Make & Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df = df.rename(columns={'Unnamed: 0': 'Make & Model'})

# %%
df.columns
# Out:
# Index(['Make & Model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')

# %%
df.head()
# Out:
#         Make & Model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.rename(columns={'Unnamed: 0': 'Make & Model'}, inplace=True)

# %%
df.head(40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8fba708d67d1> in <cell line: 1>()
# ----> 1 df.head(40)
#
# NameError: name 'df' is not defined

# %%
df['Make & Model']
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: Make & Model, dtype: object

# %%
dfsubset=df[['mpg','hp', 'wt', 'cyl']]

# %%
dfsubset.head()
# Out:
#     mpg   hp     wt  cyl
# 0  21.0  110  2.620    6
# 1  21.0  110  2.875    6
# 2  22.8   93  2.320    4
# 3  21.4  110  3.215    6
# 4  18.7  175  3.440    8

# %%
dfsubset=dfsubset.rename(columns={'cyl':'cylinders', 'hp': 'Horse power', 'wt': 'Weight', 'mpg': 'Miles_per_Gallon'})

# %%
dfsubset.head()
# Out:
#    Miles_per_Gallon  Horse_power  Weight  cylinders
# 0              21.0          110   2.620          6
# 1              21.0          110   2.875          6
# 2              22.8           93   2.320          4
# 3              21.4          110   3.215          6
# 4              18.7          175   3.440          8

# %%
dfsubset.describe().T
# Out:
#                   count        mean        std     min       25%      50%  \
# Miles_per_Gallon   32.0   20.090625   6.026948  10.400  15.42500   19.200
# Horse_power        32.0  146.687500  68.562868  52.000  96.50000  123.000
# Weight             32.0    3.217250   0.978457   1.513   2.58125    3.325
# cylinders          32.0    6.187500   1.785922   4.000   4.00000    6.000
# new                32.0   23.307875   5.200780  15.650  19.01000   22.555
#
#                        75%      max
# Miles_per_Gallon   22.8000   33.900
# Horse_power       180.0000  335.000
# Weight              3.6100    5.424
# cylinders           8.0000    8.000
# new                25.3275   35.735

# %%
dfsubset[dfsubset['Horse_power']>100]
# Out:
#     Miles_per_Gallon  Horse_power  Weight  cylinders     new
# 0               21.0          110   2.620          6  23.620
# 1               21.0          110   2.875          6  23.875
# 3               21.4          110   3.215          6  24.615
# 4               18.7          175   3.440          8  22.140
# 5               18.1          105   3.460          6  21.560
# 6               14.3          245   3.570          8  17.870
# 9               19.2          123   3.440          6  22.640
# 10              17.8          123   3.440          6  21.240
# 11              16.4          180   4.070          8  20.470
# 12              17.3          180   3.730          8  21.030
# 13              15.2          180   3.780          8  18.980
# 14              10.4          205   5.250          8  15.650
# 15              10.4          215   5.424          8  15.824
# 16              14.7          230   5.345          8  20.045
# ...

# %%
df.iloc[24]
# Out:
# Make & Model    Pontiac Firebird
# mpg                         19.2
# cyl                            8
# disp                       400.0
# hp                           175
# drat                        3.08
# wt                         3.845
# qsec                       17.05
# vs                             0
# am                             0
# gear                           3
# carb                           2
# Name: 24, dtype: object

# %%
dfsubset['Miles_per_Gallon'].mean()
# Out:
# 20.090625000000003

# %%
dfsubset['new'] = dfsubset['Weight'] + dfsubset['Miles_per_Gallon']

# %%
dfsubset['Miles_per_Gallon']
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: Miles_per_Gallon, dtype: float64

# %%
df[df['Make & Model'].str.contains ('Merc')]
# Out:
#    Make & Model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 7     Merc 240D  24.4    4  146.7   62  3.69  3.19  20.0   1   0     4     2
# 8      Merc 230  22.8    4  140.8   95  3.92  3.15  22.9   1   0     4     2
# 9      Merc 280  19.2    6  167.6  123  3.92  3.44  18.3   1   0     4     4
# 10    Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9   1   0     4     4
# 11   Merc 450SE  16.4    8  275.8  180  3.07  4.07  17.4   0   0     3     3
# 12   Merc 450SL  17.3    8  275.8  180  3.07  3.73  17.6   0   0     3     3
# 13  Merc 450SLC  15.2    8  275.8  180  3.07  3.78  18.0   0   0     3     3

# %%
df[df['Make & Model'].str.contains ('Merc')].describe()
# Out:
#              mpg       cyl        disp          hp      drat        wt  \
# count   7.000000  7.000000    7.000000    7.000000  7.000000  7.000000
# mean   19.014286  6.285714  207.157143  134.714286  3.522857  3.542857
# std     3.395305  1.799471   64.965885   47.066316  0.431343  0.333952
# min    15.200000  4.000000  140.800000   62.000000  3.070000  3.150000
# 25%    16.850000  5.000000  157.150000  109.000000  3.070000  3.315000
# 50%    17.800000  6.000000  167.600000  123.000000  3.690000  3.440000
# 75%    21.000000  8.000000  275.800000  180.000000  3.920000  3.755000
# max    24.400000  8.000000  275.800000  180.000000  3.920000  4.070000
#
#             qsec        vs   am      gear      carb
# count   7.000000  7.000000  7.0  7.000000  7.000000
# mean   19.014286  0.571429  0.0  3.571429  3.000000
# std     1.924776  0.534522  0.0  0.534522  0.816497
# min    17.400000  0.000000  0.0  3.000000  2.000000
# 25%    17.800000  0.000000  0.0  3.000000  2.500000
# ...
